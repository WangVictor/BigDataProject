# %%
import pandas as pd

# %%
all_data = pd.read_csv("../3001/Crime/NYPD_Complaint_Data_Historic.csv")
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
all_data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO              ...                      44.0
# ...

# %%
data = pd.read_csv("../3001/Crime/NYPD_Complaint_Data_Historic.csv",usecols = collist)
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
collist = ['CRM_ATPT_CPTD_CD','LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
       'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
       'HADEVELOPT','X_COORD_CD','Y_COORD_CD','Latitude','Longitude','Lat_Lon']

# %%
data.head()
# Out:
#   CRM_ATPT_CPTD_CD   LAW_CAT_CD        JURIS_DESC    BORO_NM  ADDR_PCT_CD  \
# 0        COMPLETED       FELONY  N.Y. POLICE DEPT      BRONX         44.0
# 1        COMPLETED       FELONY  N.Y. POLICE DEPT     QUEENS        103.0
# 2        COMPLETED       FELONY  N.Y. POLICE DEPT  MANHATTAN         28.0
# 3        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT     QUEENS        105.0
# 4        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  MANHATTAN         13.0
#
#   LOC_OF_OCCUR_DESC    PREM_TYP_DESC PARKS_NM HADEVELOPT  X_COORD_CD  \
# 0            INSIDE   BAR/NIGHT CLUB      NaN        NaN   1007314.0
# 1           OUTSIDE              NaN      NaN        NaN   1043991.0
# 2               NaN            OTHER      NaN        NaN    999463.0
# 3            INSIDE  RESIDENCE-HOUSE      NaN        NaN   1060183.0
# 4          FRONT OF            OTHER      NaN        NaN    987606.0
#
#    Y_COORD_CD   Latitude  Longitude                        Lat_Lon
# ...

# %%
#The name of the borough in which the incident occurred
data['BORO_NM'].unique()
# Out:
# array(['BRONX', 'QUEENS', 'MANHATTAN', 'BROOKLYN', 'STATEN ISLAND', nan], dtype=object)

# %%
#Since this analysis is based on location, if borough is empty, cannot use, discard
data[data['BORO_NM'].notnull()==False]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD        JURIS_DESC BORO_NM  ADDR_PCT_CD  \
# 1204941        COMPLETED       FELONY  N.Y. POLICE DEPT     NaN        121.0
# 1205700        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT     NaN        121.0
# 1206721        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT     NaN        121.0
# 1206901        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT     NaN        121.0
# 1206957        COMPLETED       FELONY  N.Y. POLICE DEPT     NaN        121.0
# 1207258        COMPLETED    VIOLATION  N.Y. POLICE DEPT     NaN        121.0
# 1208940        COMPLETED    VIOLATION  N.Y. POLICE DEPT     NaN        121.0
# 1209163        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT     NaN        121.0
# 1210024        COMPLETED    VIOLATION  N.Y. POLICE DEPT     NaN        121.0
# 1210226        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT     NaN        121.0
# 1210276        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT     NaN        121.0
# ...

# %%
data = data[data['BORO_NM'].notnull()==True]

# %%
#CRM_ATPT_CPTD_CD 
#Indicator of whether crime was successfully completed or attempted, but failed or was interrupted prematurely
data['CRM_ATPT_CPTD_CD'].unique()
# Out:
# array(['COMPLETED', 'ATTEMPTED', nan], dtype=object)

# %%
data[data['CRM_ATPT_CPTD_CD'].notnull()==False]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD           JURIS_DESC    BORO_NM  \
# 899205               NaN  MISDEMEANOR     N.Y. POLICE DEPT  MANHATTAN
# 1325328              NaN       FELONY     N.Y. POLICE DEPT   BROOKLYN
# 2075706              NaN  MISDEMEANOR     N.Y. POLICE DEPT     QUEENS
# 2152660              NaN  MISDEMEANOR     N.Y. POLICE DEPT      BRONX
# 4746958              NaN  MISDEMEANOR     N.Y. POLICE DEPT   BROOKLYN
# 4747214              NaN       FELONY  N.Y. HOUSING POLICE  MANHATTAN
# 4750394              NaN       FELONY  N.Y. HOUSING POLICE  MANHATTAN
#
#          ADDR_PCT_CD LOC_OF_OCCUR_DESC           PREM_TYP_DESC PARKS_NM  \
# 899205           6.0            INSIDE          BAR/NIGHT CLUB      NaN
# 1325328         83.0          FRONT OF                  STREET      NaN
# 2075706        108.0          FRONT OF                  STREET      NaN
# 2152660         47.0            INSIDE          GROCERY/BODEGA      NaN
# ...

# %%
data = data[data['CRM_ATPT_CPTD_CD'].notnull()==True]

# %%
#Level of offense: felony, misdemeanor, violation, looks clean
data['LAW_CAT_CD'].unique()
# Out:
# array(['FELONY', 'MISDEMEANOR', 'VIOLATION'], dtype=object)

# %%
#Jurisdiction responsible for incident. 
#Either internal, like Police, Transit, and Housing; or external, like Correction, Port Authority, etc.
#Text description
data['JURIS_DESC'].unique()
# Out:
# array(['N.Y. POLICE DEPT', 'N.Y. HOUSING POLICE', 'N.Y. TRANSIT POLICE',
#        'N.Y. STATE POLICE', 'DEPT OF CORRECTIONS', 'TRI-BORO BRDG TUNNL',
#        'OTHER', 'PORT AUTHORITY', 'NYC PARKS', 'HEALTH & HOSP CORP',
#        'METRO NORTH', 'LONG ISLAND RAILRD', 'STATN IS RAPID TRANS',
#        'N.Y. STATE PARKS', 'NEW YORK CITY SHERIFF OFFICE',
#        'U.S. PARK POLICE', 'NYS DEPT TAX AND FINANCE', 'AMTRACK',
#        'CONRAIL', 'POLICE DEPT NYC', 'FIRE DEPT (FIRE MARSHAL)',
#        'NYC DEPT ENVIRONMENTAL PROTECTION', 'SEA GATE POLICE DEPT',
#        'DISTRICT ATTORNEY OFFICE', 'NYS DEPT ENVIRONMENTAL CONSERVATION'], dtype=object)

# %%
#The precinct in which the incident occurred
data['ADDR_PCT_CD'].unique()
# Out:
# array([  44.,  103.,   28.,  105.,   13.,   71.,    7.,   46.,   48.,
#          19.,   41.,   14.,   67.,   17.,   61.,  102.,  110.,  108.,
#          75.,   73.,   60.,   68.,   79.,  121.,   23.,   42.,  115.,
#          52.,  122.,    1.,   72.,  109.,   24.,   81.,   90.,  112.,
#          43.,   84.,   47.,   77.,  101.,   83.,  113.,  120.,   70.,
#          69.,   66.,  114.,   76.,   63.,   45.,  106.,   10.,   78.,
#           6.,    5.,   94.,   40.,   34.,   32.,   50.,   25.,  100.,
#          18.,   20.,  111.,  107.,   30.,   49.,   88.,   26.,  123.,
#           9.,  104.,   33.,   62.,   22.,   nan])

# %%
##look at no princt crime complaints record, cannot use, discard
data[data['ADDR_PCT_CD'].notnull()==False]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD        JURIS_DESC    BORO_NM  \
# 329156         COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  MANHATTAN
# 4326270        COMPLETED       FELONY  N.Y. POLICE DEPT      BRONX
# 4937326        COMPLETED       FELONY  N.Y. POLICE DEPT  MANHATTAN
#
#          ADDR_PCT_CD LOC_OF_OCCUR_DESC PREM_TYP_DESC PARKS_NM HADEVELOPT  \
# 329156           NaN               NaN         OTHER      NaN        NaN
# 4326270          NaN               NaN           NaN      NaN        NaN
# 4937326          NaN               NaN           NaN      NaN        NaN
#
#          X_COORD_CD  Y_COORD_CD  Latitude  Longitude Lat_Lon
# 329156          NaN         NaN       NaN        NaN     NaN
# 4326270         NaN         NaN       NaN        NaN     NaN
# 4937326         NaN         NaN       NaN        NaN     NaN

# %%
data = data[data['ADDR_PCT_CD'].notnull()==True]

# %%
#Specific location of occurrence in or around the premises; inside, opposite of, front of, rear of
data['LOC_OF_OCCUR_DESC'].unique()
# Out:
# array(['INSIDE', 'OUTSIDE', nan, 'FRONT OF', 'OPPOSITE OF', 'REAR OF', ' '], dtype=object)

# %%
##for street crime or ina taxi or park, some don't have location indicator, 
#quite a lot records, but not sure this should be a problembut since probably won't use this feature anyway
data[data['LOC_OF_OCCUR_DESC'].notnull()==False]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD           JURIS_DESC        BORO_NM  \
# 2              COMPLETED       FELONY     N.Y. POLICE DEPT      MANHATTAN
# 12             COMPLETED       FELONY     N.Y. POLICE DEPT      MANHATTAN
# 13             COMPLETED       FELONY     N.Y. POLICE DEPT      MANHATTAN
# 14             COMPLETED       FELONY     N.Y. POLICE DEPT       BROOKLYN
# 20             COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT       BROOKLYN
# 22             COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT         QUEENS
# 27             COMPLETED       FELONY     N.Y. POLICE DEPT       BROOKLYN
# 29             COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT  STATEN ISLAND
# 34             COMPLETED       FELONY     N.Y. POLICE DEPT      MANHATTAN
# 37             COMPLETED       FELONY     N.Y. POLICE DEPT          BRONX
# 52             COMPLETED    VIOLATION     N.Y. POLICE DEPT       BROOKLYN
# 55             COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT       BROOKLYN
# ...

# %%
#Specific description of premises; grocery store, residence, street, etc.
data['PREM_TYP_DESC'].unique()
# Out:
# array(['BAR/NIGHT CLUB', nan, 'OTHER', 'RESIDENCE-HOUSE', 'DRUG STORE',
#        'STREET', 'RESIDENCE - APT. HOUSE', 'FAST FOOD', 'RESTAURANT/DINER',
#        'DRY CLEANER/LAUNDRY', 'PUBLIC BUILDING',
#        'RESIDENCE - PUBLIC HOUSING', 'PARK/PLAYGROUND',
#        'PARKING LOT/GARAGE (PUBLIC)', 'GAS STATION', 'TUNNEL',
#        'CHAIN STORE', 'CHECK CASHING BUSINESS', 'TRANSIT - NYC SUBWAY',
#        'BUS (NYC TRANSIT)', 'BEAUTY & NAIL SALON', 'GROCERY/BODEGA',
#        'COMMERCIAL BUILDING', 'FOOD SUPERMARKET', 'HOTEL/MOTEL',
#        'SMALL MERCHANT', 'CHURCH', 'PARKING LOT/GARAGE (PRIVATE)',
#        'DEPARTMENT STORE', 'STORE UNCLASSIFIED', 'GYM/FITNESS FACILITY',
#        'VARIETY STORE', 'CLOTHING/BOUTIQUE', 'FERRY/FERRY TERMINAL',
#        'DOCTOR/DENTIST OFFICE', 'TELECOMM. STORE', 'JEWELRY',
#        'CONSTRUCTION SITE', 'BUS STOP', 'BANK', 'HOSPITAL',
#        'TAXI (LIVERY LICENSED)', 'ATM', 'BRIDGE',
# ...

# %%
data[data['PREM_TYP_DESC'].notnull()==False]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD           JURIS_DESC        BORO_NM  \
# 1              COMPLETED       FELONY     N.Y. POLICE DEPT         QUEENS
# 471            COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT         QUEENS
# 1093           COMPLETED       FELONY     N.Y. POLICE DEPT       BROOKLYN
# 1597           COMPLETED       FELONY     N.Y. POLICE DEPT       BROOKLYN
# 1608           COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT      MANHATTAN
# 1768           COMPLETED       FELONY     N.Y. POLICE DEPT          BRONX
# 2363           COMPLETED       FELONY     N.Y. POLICE DEPT          BRONX
# 2823           COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT         QUEENS
# 2911           COMPLETED    VIOLATION     N.Y. POLICE DEPT         QUEENS
# 2937           COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT       BROOKLYN
# 2953           COMPLETED  MISDEMEANOR     N.Y. POLICE DEPT       BROOKLYN
# 3391           ATTEMPTED       FELONY     N.Y. POLICE DEPT      MANHATTAN
# ...

# %%
#Name of NYCHA housing development of occurrence, if applicable
data['HADEVELOPT'].unique()
# Out:
# array([nan, 'MARCY', 'UNION AVENUE-EAST 166TH STREET', 'MORRIS I',
#        'FARRAGUT', 'LA GUARDIA', 'BORINQUEN PLAZA I', 'REDFERN',
#        'BOSTON SECOR', 'RED HOOK WEST', 'RICHMOND TERRACE', 'LINDEN',
#        'STAPLETON', '830 AMSTERDAM AVENUE', 'SOUNDVIEW', 'WOODSIDE',
#        'BARUCH', 'BEDFORD-STUYVESANT REHAB', 'RUTGERS', 'CASTLE HILL',
#        'TOMPKINS', 'WILLIAMSBURG', 'BUSHWICK II (GROUPS B & D)',
#        'GUN HILL', 'BELMONT-SUTTER AREA', 'BUTLER', 'GRANT', 'GLENWOOD',
#        'DOUGLASS', 'THROGGS NECK', 'SOUTH BEACH', 'JACKSON', 'VAN DYKE I',
#        'EASTCHESTER GARDENS', 'WEEKSVILLE GARDENS',
#        'ATLANTIC TERMINAL SITE 4B', '1471 WATSON AVENUE', 'FOREST',
#        'WILLIAMS PLAZA', '303 VERNON AVENUE',
#        'WEST TREMONT REHAB (GROUP 3)', 'BAY VIEW', "MARINER'S HARBOR",
#        'HIGHBRIDGE GARDENS', 'GOWANUS', 'DOUGLASS ADDITION',
#        'BUSHWICK II CDA (GROUP E)', 'LATIMER GARDENS',
#        'CLAREMONT PARKWAY-FRANKLIN AVENUE', 'MACOMBS ROAD',
# ...

# %%
#Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)
data['PARKS_NM'].unique()
# Out:
# array([nan, 'MADISON SQUARE PARK', 'COLUMBUS PARK AT MANHATTAN',
#        'ARCILLA PLAYGROUND', 'CENTRAL PARK',
#        'CONEY ISLAND BEACH & BOARDWALK', 'CROTONA PARK', 'SUNSET PARK',
#        'VAN CORTLANDT PARK', 'MULLALY PARK', 'RIVERSIDE PARK',
#        'EAST RIVER PARK', 'POWER PLAYGROUND',
#        'FLUSHING MEADOWS CORONA PARK', 'ASSER LEVY PLAYGROUND',
#        'STARLIGHT PARK', 'FORT WASHINGTON PARK', 'BRYANT PARK',
#        "ST. MARY'S PARK BRONX", 'BATTERY PARK CITY', 'EWEN PARK',
#        'JACKIE ROBINSON PARK MANHATTAN', 'RIVER AVENUE PARKS',
#        'HOYT PLAYGROUND', 'CLAREMONT PARK', 'HARVARD PLAYGROUND',
#        'PAERDEGAT PARK', 'FORT GREENE PARK', 'MACOMBS DAM PARK',
#        'CHELSEA RECREATION CENTER', 'MARIA HERNANDEZ PARK',
#        'FATHER DUFFY SQUARE', 'TOMPKINS SQUARE PARK',
#        'FABER POOL AND PARK', 'HINTON PARK', 'RICHMAN (ECHO) PARK',
#        'MORNINGSIDE PARK', 'MCKINLEY PARK', 'BATTERY PARK',
# ...

# %%
#Identify all suspecious boundary points using lat and lon
lon_max = all_data['Longitude'].max()
lon_min = all_data['Longitude'].min()
lat_max = all_data['Latitude'].max()
lat_min = all_data['Latitude'].min()

# %%
#lon max all have the same lat, at the same precinct, 
#indicated in footnotes that if no reported location unclear, then recorded by princt
all_data[all_data['Longitude']==lon_max]
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1344446   736965239   04/04/2013     09:30:00   04/04/2013     09:35:00
# 1855005   732820526   03/25/2012     20:00:00   03/26/2012     03:30:00
# 2292268   220121016   05/14/2011     16:30:00   05/14/2011     16:50:00
# 2504076   712274827   12/02/2010     18:00:00          NaN          NaN
# 4963717   788311764   04/06/2006     15:00:00          NaN          NaN
#
#              RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 1344446  04/07/2013    341                   PETIT LARCENY  338.0
# 1855005  03/26/2012    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 2292268  05/14/2011    352               CRIMINAL TRESPASS  205.0
# 2504076  12/02/2010    344    ASSAULT 3 & RELATED OFFENSES  113.0
# 4963717  04/06/2006    352               CRIMINAL TRESPASS  205.0
#
#                                 PD_DESC              ...                \
# 1344446  LARCENY,PETIT FROM BUILDING,UN              ...
# ...

# %%
#still 7 records all at same location, but in 122 and 123 princt, this could be a issue
all_data[all_data['Longitude']==lon_min]
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 356518    828423996   04/02/2015     13:00:00          NaN          NaN
# 1754354   283114489   06/05/2012     02:21:00   06/05/2012     02:40:00
# 2200822   376032552   07/16/2011     17:30:00   07/16/2011     21:00:00
# 2767541   444643267   05/31/2010     21:41:00   06/03/2010     20:30:00
# 3338342   748205324   04/24/2009     19:30:00          NaN          NaN
# 3463601   395722538   01/21/2009     12:00:00   01/23/2009     16:00:00
# 4968011   908375629   10/21/2005     09:00:00   04/04/2006     12:00:00
#
#              RPT_DT  KY_CD                      OFNS_DESC  PD_CD  \
# 356518   04/15/2015    341                  PETIT LARCENY  349.0
# 1754354  06/05/2012    344   ASSAULT 3 & RELATED OFFENSES  101.0
# 2200822  07/17/2011    353  UNAUTHORIZED USE OF A VEHICLE  462.0
# 2767541  06/04/2010    361  OFF. AGNST PUB ORD SENSBLTY &  639.0
# ...

# %%
all_data[all_data['Latitude']==lat_max]
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 28413     639480003   12/07/2015     14:00:00   12/07/2015     14:15:00
# 30559     774984925   12/07/2015     10:12:00          NaN          NaN
# 74058     480163542   11/03/2015     19:30:00   11/03/2015     20:30:00
# 85539     873510252   10/23/2015     11:00:00   10/24/2015     11:00:00
# 141619    694029665   09/04/2015     20:29:00   09/15/2015     15:05:00
# 141713    891042493   08/05/2015     15:35:00   08/06/2015     09:30:00
# 141765    216057370   04/10/2015     16:00:00   05/18/2015     09:00:00
# 153324    461921448   09/06/2015     02:40:00   09/06/2015     02:45:00
# 259877    739135260   06/23/2015     12:00:00          NaN          NaN
# 341012    680357333   04/26/2015     02:40:00   04/26/2015     04:00:00
# 345160    248107931   04/21/2015     19:00:00   04/23/2015     11:00:00
# 361438    297911962   04/10/2015     23:00:00          NaN          NaN
# ...

# %%
lat_bound = all_data[all_data['Latitude']==lat_max]

# %%
#180 location with same location, all at princt 50, seem to be reasonable, high crime rate in Bronx area
lat_bound['Longitude'].unique()
# Out:
# array([-73.90252536])

# %%
all_data[all_data['Latitude']==lat_min]
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 4946884   420557582   04/17/2006     21:43:00   04/17/2006     22:50:00
#
#              RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 4946884  04/18/2006    351  CRIMINAL MISCHIEF & RELATED OF  256.0
#
#                                PD_DESC              ...                \
# 4946884  MISCHIEF, CRIMINAL 4, BY FIRE              ...
#
#         ADDR_PCT_CD LOC_OF_OCCUR_DESC    PREM_TYP_DESC PARKS_NM  HADEVELOPT  \
# 4946884       123.0               NaN  PARK/PLAYGROUND      NaN         NaN
#
#         X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 4946884   915028.0   120829.0  40.498061 -74.248894
#
#                                Lat_Lon
# 4946884  (40.498060701, -74.248893743)
#
# [1 rows x 24 columns]

# %%
#identify all suspicious points
p1=[40.739224294, -73.700315857]
p2=[40.507750107, -74.255075543]
p3=[40.498060701, -74.248893743]
p4=[40.912723396, -73.902525358]

# %%
import pyproj 
import folium

# %%
#project on a map to check if location resonable
lat_lon_map = folium.Map(location=[40.759537, -73.984216],zoom_start=10)
folium.Marker(p1, popup='p1').add_to(lat_lon_map)
folium.Marker(p2, popup='p2').add_to(lat_lon_map)
folium.Marker(p3, popup='p3').add_to(lat_lon_map)
folium.Marker(p4, popup='p4').add_to(lat_lon_map)
lat_lon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
p1 = pyproj.Proj(init='epsg:2263',preserve_units=True)
p2 = pyproj.Proj(init='epsg:4326')
#map_s = folium.Map(location=[lat,lon],zoom_start=15)
#folium.Marker([45.3288, -121.6625], popup='Mt. Hood Meadows').add_to(map_1)

# %%
#should check data consistency first, i.e the xy_cordinate and geographical cordination is the consistent
#but is it part of data cleanin?

#for i in all_data.index:
#    lon, lat = pyproj.transform(p1,p2,all_data['X_COORD_CD'][i], all_data['Y_COORD_CD'][i])
#    if abs(lon-all_data['Longitude'][i])>=10**(-5) or abs(lat-all_data['Latitude'][i])>=10**(-5):
#        print(i)

# %%
#identify all suspicious points using xy cordinate
x_max = all_data['X_COORD_CD'].max()
x_min = all_data['X_COORD_CD'].min()
y_max = all_data['Y_COORD_CD'].max()
y_min = all_data['Y_COORD_CD'].min()

# %%
#all with same location
data[data['X_COORD_CD']==x_max]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD        JURIS_DESC BORO_NM  ADDR_PCT_CD  \
# 1344446        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  QUEENS        105.0
# 1855005        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  QUEENS        105.0
# 2292268        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  QUEENS        105.0
# 2504076        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  QUEENS        105.0
# 4963717        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  QUEENS        105.0
#
#         LOC_OF_OCCUR_DESC          PREM_TYP_DESC PARKS_NM HADEVELOPT  \
# 1344446            INSIDE  DOCTOR/DENTIST OFFICE      NaN        NaN
# 1855005          FRONT OF                 STREET      NaN        NaN
# 2292268            INSIDE         BAR/NIGHT CLUB      NaN        NaN
# 2504076            INSIDE    COMMERCIAL BUILDING      NaN        NaN
# 4963717            INSIDE        RESIDENCE-HOUSE      NaN        NaN
#
#          X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# ...

# %%
lon5, lat5 = pyproj.transform(p1,p2,1067298.0, 208735.0)
p5 = [lat5, lon5]

# %%
data[data['X_COORD_CD']==x_min]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD        JURIS_DESC        BORO_NM  \
# 356518         COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  STATEN ISLAND
# 1754354        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  STATEN ISLAND
# 2200822        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  STATEN ISLAND
# 2767541        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  STATEN ISLAND
# 3338342        COMPLETED    VIOLATION  N.Y. POLICE DEPT  STATEN ISLAND
# 3463601        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  STATEN ISLAND
# 4968011        ATTEMPTED       FELONY  N.Y. POLICE DEPT  STATEN ISLAND
#
#          ADDR_PCT_CD LOC_OF_OCCUR_DESC    PREM_TYP_DESC PARKS_NM HADEVELOPT  \
# 356518         122.0          FRONT OF  RESIDENCE-HOUSE      NaN        NaN
# 1754354        122.0          FRONT OF  RESIDENCE-HOUSE      NaN        NaN
# 2200822        122.0          FRONT OF           STREET      NaN        NaN
# 2767541        123.0            INSIDE  RESIDENCE-HOUSE      NaN        NaN
# ...

# %%
lon6, lat6 = pyproj.transform(p1,p2,913319.0, 124364.00)
p6 = [lat6, lon6]

# %%
data[data['Y_COORD_CD']==y_max]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD        JURIS_DESC BORO_NM  ADDR_PCT_CD  \
# 28413          COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT   BRONX         50.0
# 30559          COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT   BRONX         50.0
# 74058          COMPLETED    VIOLATION  N.Y. POLICE DEPT   BRONX         50.0
# 85539          COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT   BRONX         50.0
# 141619         COMPLETED       FELONY  N.Y. POLICE DEPT   BRONX         50.0
# 141713         COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT   BRONX         50.0
# 141765         COMPLETED       FELONY  N.Y. POLICE DEPT   BRONX         50.0
# 153324         COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT   BRONX         50.0
# 259877         COMPLETED       FELONY  N.Y. POLICE DEPT   BRONX         50.0
# 341012         COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT   BRONX         50.0
# 345160         COMPLETED    VIOLATION  N.Y. POLICE DEPT   BRONX         50.0
# ...

# %%
lon7, lat7 = pyproj.transform(p1,p2,1011192.0, 271820.0)
p7 = [lat7, lon7]

# %%
data[data['Y_COORD_CD']==y_min]
# Out:
#         CRM_ATPT_CPTD_CD   LAW_CAT_CD        JURIS_DESC        BORO_NM  \
# 4946884        COMPLETED  MISDEMEANOR  N.Y. POLICE DEPT  STATEN ISLAND
#
#          ADDR_PCT_CD LOC_OF_OCCUR_DESC    PREM_TYP_DESC PARKS_NM HADEVELOPT  \
# 4946884        123.0               NaN  PARK/PLAYGROUND      NaN        NaN
#
#          X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 4946884    915028.0    120829.0  40.498061 -74.248894
#
#                                Lat_Lon
# 4946884  (40.498060701, -74.248893743)

# %%
lon8, lat8 = pyproj.transform(p1,p2,915028.0, 120829.0)
p8 = [lat8, lon8]

# %%
all_data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO              ...                      44.0
# ...

# %%
test_map = folium.Map(location=[40.759537, -73.984216],zoom_start=10)
folium.Marker(p5, popup='p5').add_to(test_map)
folium.Marker(p6, popup='p6').add_to(test_map)
folium.Marker(p7, popup='p7').add_to(test_map)
folium.Marker(p8, popup='p8').add_to(test_map)

# %%
test_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
